# %%
import numpy as np
import matplotlib.pyplot as pt

# %%
x=np.random.randint(1,100,(1,100))
y=np.random.randint(10,100,(1,100))

pt.scatter(x,y,label="stars",marker="*",color="blue",s=30)

pt.xlabel('X')
pt.ylabel('Y')
pt.title('Scatter-Plot')
pt.show()
