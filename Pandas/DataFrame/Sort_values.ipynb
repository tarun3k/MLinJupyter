# %%
import pandas as pd

# %%
nba=pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_values("Number").head()
# Out:
#                     Name                  Team  Number Position   Age Height  \
# 0          Avery Bradley        Boston Celtics     0.0       PG  25.0    6-2
# 291      Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0    6-5
# 22          Shane Larkin         Brooklyn Nets     0.0       PG  23.0   5-11
# 393      Emmanuel Mudiay        Denver Nuggets     0.0       PG  20.0    6-5
# 141  Willie Cauley-Stein      Sacramento Kings     0.0        C  22.0    7-0
#
#      Weight           College     Salary
# 0     180.0             Texas  7730337.0
# 291   220.0  UC Santa Barbara    55722.0
# 22    175.0        Miami (FL)  1500000.0
# 393   200.0               NaN  3102240.0
# 141   240.0          Kentucky  3398280.0

# %%
nba.sort_values(["Number","Age"]).head()
# Out:
#                     Name              Team  Number Position   Age Height  \
# 356         Aaron Gordon     Orlando Magic     0.0       PF  20.0    6-9
# 393      Emmanuel Mudiay    Denver Nuggets     0.0       PG  20.0    6-5
# 141  Willie Cauley-Stein  Sacramento Kings     0.0        C  22.0    7-0
# 188       Andre Drummond   Detroit Pistons     0.0        C  22.0   6-11
# 347      Josh Richardson        Miami Heat     0.0       SG  22.0    6-6
#
#      Weight      College     Salary
# 356   220.0      Arizona  4171680.0
# 393   200.0          NaN  3102240.0
# 141   240.0     Kentucky  3398280.0
# 188   279.0  Connecticut  3272091.0
# 347   200.0    Tennessee   525093.0

# %%
nba.sort_values(["Number","Age"],ascending=[True,False],inplace=True)
nba.tail()
# Out:
#                Name                Team  Number Position   Age Height  Weight  \
# 372     Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10   250.0
# 5      Amir Johnson      Boston Celtics    90.0       PF  29.0    6-9   240.0
# 68   Lucas Nogueira     Toronto Raptors    92.0        C  23.0    7-0   220.0
# 1       Jae Crowder      Boston Celtics    99.0       SF  25.0    6-6   235.0
# 457             NaN                 NaN     NaN      NaN   NaN    NaN     NaN
#
#        College      Salary
# 372     Kansas   3300000.0
# 5          NaN  12000000.0
# 68         NaN   1842000.0
# 1    Marquette   6796117.0
# 457        NaN         NaN

# %%
nba.sort_values("Salary",na_position="last").tail() #na_position tell where place the Nan value onto the dataset
# Out:
#                Name                 Team  Number Position   Age Height  \
# 171   Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6
# 2      John Holland       Boston Celtics    30.0       SG  27.0    6-5
# 273  Alex Stepheson    Memphis Grizzlies    35.0       PF  28.0   6-10
# 46      Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9
# 457             NaN                  NaN     NaN      NaN   NaN    NaN
#
#      Weight            College  Salary
# 171   225.0               Duke     NaN
# 2     205.0  Boston University     NaN
# 273   270.0                USC     NaN
# 46    254.0               Duke     NaN
# 457     NaN                NaN     NaN
