# %%
import pandas as pd

# %%
nba=pd.read_csv('nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['Sport']='Basketball'
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba.insert(3,column='Nationality',value='USA')# insert column at specififc index
nba.head()
# Out:
#             Name            Team  Number Nationality Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0         USA       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0         USA       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0         USA       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0         USA       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0         USA       PF  29.0   6-10
#
#    Weight            College     Salary       Sport
# 0   180.0              Texas  7730337.0  Basketball
# 1   235.0          Marquette  6796117.0  Basketball
# 2   205.0  Boston University        NaN  Basketball
# 3   185.0      Georgia State  1148640.0  Basketball
# 4   231.0                NaN  5000000.0  Basketball

# %%
nba.tail()
nba.sort_values(by='Name')#just for fun bro
# Out:
#                     Name                    Team  Number Nationality Position  \
# 152         Aaron Brooks           Chicago Bulls     0.0         USA       PG
# 356         Aaron Gordon           Orlando Magic     0.0         USA       PF
# 328       Aaron Harrison       Charlotte Hornets     9.0         USA       SG
# 404        Adreian Payne  Minnesota Timberwolves    33.0         USA       PF
# 312           Al Horford           Atlanta Hawks    15.0         USA        C
# 330         Al Jefferson       Charlotte Hornets    25.0         USA        C
# 428      Al-Farouq Aminu  Portland Trail Blazers     8.0         USA       SF
# 368        Alan Anderson      Washington Wizards     6.0         USA       SG
# 135        Alan Williams            Phoenix Suns    15.0         USA        C
# 444           Alec Burks               Utah Jazz    10.0         USA       SG
# 128             Alex Len            Phoenix Suns    21.0         USA        C
# ...
