# %%
import pandas as pd

# %%
pk=pd.read_csv('pokemon.csv',squeeze=True)
pk.sort_values(by=['Pokemon'],ascending=False)#for Descending the CSV file 
pk
# Out:
#         Pokemon      Type
# 0     Bulbasaur     Grass
# 1       Ivysaur     Grass
# 2      Venusaur     Grass
# 3    Charmander      Fire
# 4    Charmeleon      Fire
# 5     Charizard      Fire
# 6      Squirtle     Water
# 7     Wartortle     Water
# 8     Blastoise     Water
# 9      Caterpie       Bug
# 10      Metapod       Bug
# 11   Butterfree       Bug
# 12       Weedle       Bug
# 13       Kakuna       Bug
# 14     Beedrill       Bug
# 15       Pidgey    Normal
# 16    Pidgeotto    Normal
# 17      Pidgeot    Normal
# 18      Rattata    Normal
# 19     Raticate    Normal
# 20      Spearow    Normal
# 21       Fearow    Normal
# 22        Ekans    Poison
# 23        Arbok    Poison
# 24      Pikachu  Electric
# 25       Raichu  Electric
# 26    Sandshrew    Ground
# 27    Sandslash    Ground
# 28      Nidoran    Poison
# 29     Nidorina    Poison
# ..          ...       ...
# 691   Clauncher     Water
# 692   Clawitzer     Water
# 693  Helioptile  Electric
# ...

# %%
pk.sort_values(by=['Pokemon'],inplace=True)
pk
# Out:
#         Pokemon      Type
# 459   Abomasnow     Grass
# 62         Abra   Psychic
# 358       Absol      Dark
# 616    Accelgor       Bug
# 680   Aegislash     Steel
# 141  Aerodactyl      Rock
# 305      Aggron     Steel
# 189       Aipom    Normal
# 64     Alakazam   Psychic
# 593   Alomomola     Water
# 333     Altaria    Dragon
# 697      Amaura      Rock
# 423     Ambipom    Normal
# 590   Amoonguss     Grass
# 180    Ampharos  Electric
# 346     Anorith      Rock
# 23        Arbok    Poison
# 58     Arcanine      Fire
# 492      Arceus    Normal
# 565      Archen      Rock
# 566    Archeops      Rock
# 167     Ariados       Bug
# 347     Armaldo      Rock
# 682  Aromatisse     Fairy
# 303        Aron     Steel
# 143    Articuno       Ice
# 530      Audino    Normal
# 698     Aurorus      Rock
# 712     Avalugg       Ice
# 609        Axew    Dragon
# ..          ...       ...
# 69   Weepinbell     Grass
# 109     Weezing    Poison
# 546  Whimsicott     Grass
# ...
